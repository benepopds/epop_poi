# %%
# Perform imports here:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from pytz import timezone
from sqlalchemy import create_engine
import math
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import gc
from joblib import Parallel, delayed
import joblib

# %%
#df = pd.read_pickle("OLI_SELL.pk")
df = pd.read_pickle("data/GSS0713.pk")
#df = pd.read_pickle("HMA_SELL.pk")
df.head(1)
# Out:
#   SELL_AMOUNT STOCK_AMOUNT REVISE_STOCK_AMOUNT     STOCK_ID ITEM_ID  \
# 0           0          726                 726  16437651001  115022
#
#                UPT_DT COLLECT_DAY       UPT_ID     REG_DT  ITEM_NUM  \
# 0 2018-07-13 13:36:16  2018-06-01  FILTER ALGO 2018-06-01  16437651
#
#                                  GOODS_NAME  \
# 0  [바비리스] 1600W 이온 헤어드라이기 접이식/2단/쿨샷 5383K +
#
#                                        COLLECT_URL  NORMAL_PRICE_SITE  \
# 0  http://www.gsshop.com/prd/prd.gs?prdid=16437651              27800
#
#   BRAND_NAME  SITE_NO  CATE_NAMES BRAND SELL
# 0       바비리스        1  바디/헤어>헤어케어  init    0

# %%
df.SELL_AMOUNT.value_counts().reset_index().sort_values("index",ascending=False)
# Out:
#      index  SELL_AMOUNT
# 136  499.0           29
# 194  498.0           11
# 243  497.0            6
# 250  496.0            5
# 229  495.0            7
# 176  494.0           15
# 188  493.0           12
# 259  492.0            4
# 238  491.0            6
# 248  490.0            5
# 235  489.0            6
# 236  488.0            6
# 222  487.0            8
# 325  486.0            2
# 237  485.0            6
# 277  484.0            4
# 279  483.0            3
# 278  482.0            3
# 280  481.0            3
# 354  480.0            1
# 324  479.0            2
# 318  478.0            2
# 262  477.0            4
# 263  476.0            4
# 281  474.0            3
# 395  473.0            1
# 331  472.0            2
# 260  471.0            4
# 363  470.0            1
# 337  469.0            2
# ..     ...          ...
# 47    29.0          128
# 35    28.0          158
# 31    27.0          174
# 55    26.0          109
# 22    25.0          466
# 34    24.0          168
# 39    23.0          152
# 38    22.0          154
# 45    21.0          137
# 17    20.0          595
# 27    19.0          309
# 29    18.0          244
# 19    17.0          545
# 12    16.0          829
# 14    15.0          640
# 13    14.0          756
# 16    13.0          621
# 15    12.0          624
# 18    11.0          581
# 9     10.0         1119
# 10     9.0         1033
# 8      8.0         1357
# 7      7.0         1756
# 6      6.0         2216
# 5      5.0         3254
# 4      4.0         4991
# 3      3.0         8637
# 2      2.0        19994
# 1      1.0       104237
# 0      0.0      2146102
#
# [397 rows x 2 columns]

# %%
df.SELL_AMOUNT.value_counts().reset_index().sort_values("index",ascending=False)[25:]

# %%
df.SELL_AMOUNT.value_counts().reset_index().sort_values("index",ascending=False)[50:]

# %%
df.SELL_AMOUNT.max()

# %%
n = 500
out = df[df.SELL_AMOUNT>n].STOCK_ID.unique()

# %%
df[df.SELL_AMOUNT>n].groupby("BRAND").size()

# %%
df[df.SELL_AMOUNT>n].groupby("BRAND").ITEM_ID.nunique()

# %%
df[df.SELL_AMOUNT>n].groupby("BRAND").STOCK_ID.nunique()

# %%
df[(df.STOCK_ID.isin(out))&(df.BRAND=="AP")].sort_values(["ITEM_ID", "STOCK_ID", "COLLECT_DAY"])

# %%
df[(df.STOCK_ID.isin(out))&(df.BRAND=="LG")].sort_values(["ITEM_ID", "STOCK_ID", "COLLECT_DAY"])

# %%
df[(df.STOCK_ID.isin(out))&(df.BRAND=="LOREAL")].sort_values(["ITEM_ID", "STOCK_ID", "COLLECT_DAY"])

# %%
df[(df.STOCK_ID.isin(out))&(df.BRAND=="LVMH")].sort_values(["ITEM_ID", "STOCK_ID", "COLLECT_DAY"])

# %% [markdown]
# ## 루이비똥 봐보자 ...

# %%
n

# %%
lvmh = df[(df.SELL_AMOUNT<n)&(df.BRAND=="LVMH")]

# %%
lvmh.SELL.sort_values(ascending=False)

# %%
lvmh.loc[lvmh.SELL.sort_values(ascending=False).index[1:100]].SELL_AMOUNT

# %%
lvmh[lvmh.STOCK_ID==lvmh.loc[504031].STOCK_ID]

# %%
lvmh[(lvmh.SELL_AMOUNT < 480)|(lvmh.SELL_AMOUNT > 500)].SELL.sum()

# %%
temp = lvmh.SELL_AMOUNT.value_counts().sort_values(ascending=False)
temp2 = temp[temp>1].reset_index()
shit = temp2[temp2["index"]>100]['index']

# %%
lvmh[-lvmh.SELL_AMOUNT.isin(shit)].SELL.sum()

# %% [markdown]
# ## 브랜드별 / 전체 매출액

# %%
df=pd.read_pickle('data/OLI0713.pk')
df[df.SELL!=0][['ITEM_ID','SELL','BRAND','SELL_AMOUNT']].head(2)
# Out:
#    ITEM_ID   SELL BRAND SELL_AMOUNT
# 1  8758383  69000  LVMH           1
# 2  8758383  69000  LVMH           1

# %%
pd.DataFrame(df.groupby('BRAND').SELL.sum().astype(str)).T
# Out:
# BRAND           AP           LG       LOREAL        LVMH           init
# SELL   193578900.0  521160650.0  428640100.0  98265900.0  10523470450.0

# %%
df[df.SELL_AMOUNT<500].to_pickle('data/OLI0713.pk')

# %%
df.SELL_AMOUNT.sort_values(ascending=False)
# Out:
# 130414    99972
# 175734    99970
# 56968     99966
# 186151    99957
# 221558    99956
# 234197    99953
# 55843     99905
# 260492    99895
# 144412    99814
# 138056    99813
# 19876     99783
# 55271     99748
# 258667    99747
# 214133    99721
# 177764    99715
# 98420     99694
# 213498    99686
# 119510    99666
# 214108    99622
# 25210     99533
# 222942    99449
# 209962    99393
# 261132     6604
# 148824     3671
# 148823     1454
# 27124      1288
# 49868      1080
# 167743     1065
# 245445      951
# 202163      944
#           ...
# 263334     None
# 263335     None
# 263349     None
# 263350     None
# 263357     None
# 263361     None
# 263363     None
# 263376     None
# 263378     None
# 263386     None
# 263391     None
# 263392     None
# 263402     None
# 263415     None
# 263434     None
# 263444     None
# 263464     None
# 263471     None
# 263481     None
# 263499     None
# 263662     None
# 263691     None
# 263723     None
# 263727     None
# 263749     None
# 263753     None
# 263777     None
# 263796     None
# 263804     None
# 263807     None
# Name: SELL_AMOUNT, Length: 263808, dtype: object

# %% [markdown]
# ## 판매량 계산

# %%
df.groupby("BRAND").SELL.sum().reset_index()
# Out:
#     BRAND          SELL
# 0      AP  4.869031e+09
# 1      LG  4.793041e+09
# 2  LOREAL  1.969938e+09
# 3    LVMH  7.868710e+08
# 4    init  4.364687e+10

# %%
df[df.SELL_AMOUNT<500].groupby("BRAND").SELL.sum().reset_index()
# Out:
#     BRAND          SELL
# 0      AP  4.869031e+09
# 1      LG  4.793041e+09
# 2  LOREAL  1.969938e+09
# 3    LVMH  7.868710e+08
# 4    init  4.364687e+10

# %%
df[df.SELL_AMOUNT<100].groupby("BRAND").SELL.sum().reset_index()

# %% [markdown]
# ## 일단 정리하자~~

# %%
OLI = pd.read_pickle("OLI_SELL.pk")
GSS = pd.read_pickle("GSS_SELL.pk")
HMA = pd.read_pickle("HMA_SELL.pk")

# %%
#OLI[OLI.SELL_AMOUNT<500]
HMA = HMA[HMA.SELL_AMOUNT<500]
GSS = GSS[GSS.SELL_AMOUNT<500]

# %%
n = 500
lvmh = GSS[(GSS.SELL_AMOUNT<n)&(GSS.BRAND=="LVMH")]
temp = lvmh.SELL_AMOUNT.value_counts().sort_values(ascending=False)
temp2 = temp[temp>1].reset_index()
shit = temp2[temp2["index"]>100]['index']

# %%
GSS[-((GSS.BRAND=="LVMH")&(GSS.SELL_AMOUNT.isin(shit)))].groupby("BRAND").SELL.sum()
# Out:
# BRAND
# AP        4.869031e+09
# LG        4.793041e+09
# LOREAL    1.969938e+09
# LVMH      7.868710e+08
# init      4.364687e+10
# Name: SELL, dtype: float64

# %%
HMA.groupby("BRAND").SELL.sum()
# Out:
# BRAND
# AP        2.055956e+09
# LG        1.048695e+09
# LOREAL    2.701683e+09
# LVMH      4.114830e+08
# init      7.396535e+09
# Name: SELL, dtype: float64

# %%
OLI.groupby("BRAND").SELL.sum()
# Out:
# BRAND
# AP        1.935789e+08
# LG        5.211606e+08
# LOREAL    4.382521e+08
# LVMH      9.826590e+07
# init      1.145958e+11
# Name: SELL, dtype: float64

# %%
GSS=GSS[-((GSS.BRAND=="LVMH")&(GSS.SELL_AMOUNT.isin(shit)))]

# %%
OLI.to_pickle("OLI0713.pk")
HMA.to_pickle("HMA0713.pk")
GSS.to_pickle("GSS0713.pk")

# %% [markdown]
# ## 정리한 거 계산 ..

# %%
OLI_pivot = OLI.groupby(["BRAND", "CATE_NAMES"]).SELL.sum().reset_index().pivot(index="CATE_NAMES", columns="BRAND", values="SELL")
HMA_pivot = HMA.groupby(["BRAND", "CATE_NAMES"]).SELL.sum().reset_index().pivot(index="CATE_NAMES", columns="BRAND", values="SELL")
GSS_pivot = GSS.groupby(["BRAND", "CATE_NAMES"]).SELL.sum().reset_index().pivot(index="CATE_NAMES", columns="BRAND", values="SELL")

# %%
OLI_pivot["SITE_NAME"] = "Oliveyoung"
GSS_pivot["SITE_NAME"] = "GSSHOP"
HMA_pivot["SITE_NAME"] = "HMALL"

# %%
report = pd.concat([OLI_pivot, GSS_pivot, HMA_pivot]).reset_index()
report = report.sort_values(["CATE_NAMES", "SITE_NAME"]).reset_index(drop=True)
report[["CATE_NAMES", "SITE_NAME", "AP", "LG", "LOREAL", "LVMH"]].to_csv("REPORT0713.csv", index=False)
report[["AP", "LG", "LOREAL", "LVMH", "SITE_NAME"]].groupby("SITE_NAME").sum().to_csv("REPORT20713.csv")

# %% [markdown]
# ## 연습장

# %%
old[(old.ITEM_ID==8764787)&(old.STOCK_ID=='-1251111349027131874')]
# Out:
#       SELL_AMOUNT STOCK_AMOUNT REVISE_STOCK_AMOUNT              STOCK_ID  \
# 46422           0          210                 210  -1251111349027131874
# 46423        None          106                 106  -1251111349027131874
# 46424        None            0                   0  -1251111349027131874
# 46425           0            0                   0  -1251111349027131874
# 46426           0            0                   0  -1251111349027131874
# 46427        None           59                None  -1251111349027131874
# 46428        None           37                  37  -1251111349027131874
# 46429        None           26                  26  -1251111349027131874
# 46430        None           14                  14  -1251111349027131874
# 46431        None          141                None  -1251111349027131874
# 46432        None          118                 118  -1251111349027131874
# 46433        None          106                 106  -1251111349027131874
# 46434        None           62                  62  -1251111349027131874
# 46435        None          165                None  -1251111349027131874
# 46436        None          157                 157  -1251111349027131874
# 46437        None          139                 139  -1251111349027131874
# 46438        None           99                  99  -1251111349027131874
# 46439        None          166                None  -1251111349027131874
# 46440        None          145                 145  -1251111349027131874
# 46441        None          113                 113  -1251111349027131874
# 46442        None           93                  93  -1251111349027131874
# 46443        None           62                  62  -1251111349027131874
# 46444        None           34                  34  -1251111349027131874
# 46445        None            0                   0  -1251111349027131874
# 46446        None           96                None  -1251111349027131874
# 46447           0           96                  96  -1251111349027131874
# 46448        None           69                  69  -1251111349027131874
# 46449        None           23                  23  -1251111349027131874
# 46450           0           23                  23  -1251111349027131874
#
#        ITEM_ID              UPT_DT COLLECT_DAY       UPT_ID     REG_DT  \
# 46422  8764787 2018-07-11 17:05:59  2018-06-02  FILTER ALGO 2018-06-02
# 46423  8764787 2018-07-11 17:05:59  2018-06-03  FILTER ALGO 2018-06-03
# 46424  8764787 2018-07-11 17:05:59  2018-06-04  FILTER ALGO 2018-06-04
# 46425  8764787 2018-07-11 17:05:59  2018-06-05  FILTER ALGO 2018-06-05
# 46426  8764787 2018-07-11 17:05:59  2018-06-06  FILTER ALGO 2018-06-06
# 46427  8764787 2018-07-11 17:05:59  2018-06-07  FILTER ALGO 2018-06-07
# 46428  8764787 2018-07-11 17:05:59  2018-06-08  FILTER ALGO 2018-06-08
# 46429  8764787 2018-07-11 17:05:59  2018-06-09  FILTER ALGO 2018-06-09
# 46430  8764787 2018-07-11 17:05:59  2018-06-10  FILTER ALGO 2018-06-10
# 46431  8764787 2018-07-11 17:05:59  2018-06-11  FILTER ALGO 2018-06-11
# 46432  8764787 2018-07-11 17:05:59  2018-06-12  FILTER ALGO 2018-06-12
# 46433  8764787 2018-07-11 17:05:59  2018-06-13  FILTER ALGO 2018-06-13
# 46434  8764787 2018-07-11 17:05:59  2018-06-14  FILTER ALGO 2018-06-14
# 46435  8764787 2018-07-11 17:05:59  2018-06-15  FILTER ALGO 2018-06-15
# 46436  8764787 2018-07-11 17:05:59  2018-06-16  FILTER ALGO 2018-06-16
# 46437  8764787 2018-07-11 17:05:59  2018-06-17  FILTER ALGO 2018-06-17
# 46438  8764787 2018-07-11 17:05:59  2018-06-18  FILTER ALGO 2018-06-18
# 46439  8764787 2018-07-11 17:05:59  2018-06-19  FILTER ALGO 2018-06-19
# 46440  8764787 2018-07-11 17:05:59  2018-06-20  FILTER ALGO 2018-06-20
# 46441  8764787 2018-07-11 17:05:59  2018-06-21  FILTER ALGO 2018-06-21
# 46442  8764787 2018-07-11 17:05:59  2018-06-22  FILTER ALGO 2018-06-22
# 46443  8764787 2018-07-11 17:05:59  2018-06-23  FILTER ALGO 2018-06-23
# 46444  8764787 2018-07-11 17:05:59  2018-06-24  FILTER ALGO 2018-06-24
# 46445  8764787 2018-07-11 17:05:59  2018-06-25  FILTER ALGO 2018-06-25
# 46446  8764787 2018-07-11 17:05:59  2018-06-26  FILTER ALGO 2018-06-26
# 46447  8764787 2018-07-11 17:05:59  2018-06-27  FILTER ALGO 2018-06-27
# 46448  8764787 2018-07-11 17:05:59  2018-06-28  FILTER ALGO 2018-06-28
# 46449  8764787 2018-07-11 17:05:59  2018-06-29  FILTER ALGO 2018-06-29
# 46450  8764787 2018-07-11 17:05:59  2018-06-30  FILTER ALGO 2018-06-30
#
#             ITEM_NUM  NORMAL_PRICE_SITE BRAND_NAME  SITE_NO   CATE_NAMES  \
# 46422  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46423  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46424  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46425  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46426  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46427  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46428  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46429  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46430  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46431  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46432  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46433  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46434  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46435  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46436  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46437  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46438  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46439  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46440  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46441  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46442  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46443  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46444  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46445  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46446  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46447  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46448  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46449  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
# 46450  A000000112419              19000        비욘드        4  스킨케어>베이직 기초
#
#       BRAND SELL
# 46422    LG    0
# 46423    LG  NaN
# 46424    LG  NaN
# 46425    LG    0
# 46426    LG    0
# 46427    LG  NaN
# 46428    LG  NaN
# 46429    LG  NaN
# 46430    LG  NaN
# 46431    LG  NaN
# 46432    LG  NaN
# 46433    LG  NaN
# 46434    LG  NaN
# 46435    LG  NaN
# 46436    LG  NaN
# 46437    LG  NaN
# 46438    LG  NaN
# 46439    LG  NaN
# 46440    LG  NaN
# 46441    LG  NaN
# 46442    LG  NaN
# 46443    LG  NaN
# 46444    LG  NaN
# 46445    LG  NaN
# 46446    LG  NaN
# 46447    LG    0
# 46448    LG  NaN
# 46449    LG  NaN
# 46450    LG    0

# %%
OLI[(OLI.ITEM_ID==11961831)&(OLI.STOCK_ID=='7405510148804182974')]
# Out:
#        SELL_AMOUNT STOCK_AMOUNT REVISE_STOCK_AMOUNT             STOCK_ID  \
# 253731           0        99999               99999  7405510148804182974
# 253732           0        99999               99999  7405510148804182974
# 253733           0        99999               99999  7405510148804182974
# 253734           0        99999               99999  7405510148804182974
# 253735           0        99999               99999  7405510148804182974
# 253736           0        99999               99999  7405510148804182974
# 253737           0        99999               99999  7405510148804182974
# 253738           0        99999               99999  7405510148804182974
# 253739           0        99999               99999  7405510148804182974
# 253740           0        99999               99999  7405510148804182974
# 253741           0        99999               99999  7405510148804182974
# 253742           0        99999               99999  7405510148804182974
# 253743           0        99999               99999  7405510148804182974
# 253744           0        99999               99999  7405510148804182974
# 253745           0        99999               99999  7405510148804182974
# 253746           0        99999               99999  7405510148804182974
# 253747           0        99999               99999  7405510148804182974
# 253748           0        99999               99999  7405510148804182974
# 253749           0        99999               99999  7405510148804182974
# 253750           0        99999               99999  7405510148804182974
# 253751           0        99999               99999  7405510148804182974
# 253752           0        99999               99999  7405510148804182974
# 253753           0        99999               99999  7405510148804182974
# 253754           0        99999               99999  7405510148804182974
# 253755           0        99999               99999  7405510148804182974
# 253756           0        99999               99999  7405510148804182974
# 253757           0        99999               99999  7405510148804182974
# 253758           0        99999               99999  7405510148804182974
# 253759           0        99999               99999  7405510148804182974
#
#          ITEM_ID              UPT_DT COLLECT_DAY       UPT_ID     REG_DT  \
# 253731  11961831 2018-07-13 13:09:06  2018-06-02  FILTER ALGO 2018-06-02
# 253732  11961831 2018-07-13 13:09:06  2018-06-03  FILTER ALGO 2018-06-03
# 253733  11961831 2018-07-13 13:09:06  2018-06-04  FILTER ALGO 2018-06-04
# 253734  11961831 2018-07-13 13:09:06  2018-06-05  FILTER ALGO 2018-06-05
# 253735  11961831 2018-07-13 13:09:06  2018-06-06  FILTER ALGO 2018-06-06
# 253736  11961831 2018-07-13 13:09:06  2018-06-07  FILTER ALGO 2018-06-07
# 253737  11961831 2018-07-13 13:09:06  2018-06-08  FILTER ALGO 2018-06-08
# 253738  11961831 2018-07-13 13:09:06  2018-06-09  FILTER ALGO 2018-06-09
# 253739  11961831 2018-07-13 13:09:06  2018-06-10  FILTER ALGO 2018-06-10
# 253740  11961831 2018-07-13 13:09:06  2018-06-11  FILTER ALGO 2018-06-11
# 253741  11961831 2018-07-13 13:09:06  2018-06-12  FILTER ALGO 2018-06-12
# 253742  11961831 2018-07-13 13:09:06  2018-06-13  FILTER ALGO 2018-06-13
# 253743  11961831 2018-07-13 13:09:06  2018-06-14  FILTER ALGO 2018-06-14
# 253744  11961831 2018-07-13 13:09:06  2018-06-15  FILTER ALGO 2018-06-15
# 253745  11961831 2018-07-13 13:09:06  2018-06-16  FILTER ALGO 2018-06-16
# 253746  11961831 2018-07-13 13:09:06  2018-06-17  FILTER ALGO 2018-06-17
# 253747  11961831 2018-07-13 13:09:06  2018-06-18  FILTER ALGO 2018-06-18
# 253748  11961831 2018-07-13 13:09:06  2018-06-19  FILTER ALGO 2018-06-19
# 253749  11961831 2018-07-13 13:09:06  2018-06-20  FILTER ALGO 2018-06-20
# 253750  11961831 2018-07-13 13:09:06  2018-06-21  FILTER ALGO 2018-06-21
# 253751  11961831 2018-07-13 13:09:06  2018-06-22  FILTER ALGO 2018-06-22
# 253752  11961831 2018-07-13 13:09:06  2018-06-23  FILTER ALGO 2018-06-23
# 253753  11961831 2018-07-13 13:09:06  2018-06-24  FILTER ALGO 2018-06-24
# 253754  11961831 2018-07-13 13:09:06  2018-06-25  FILTER ALGO 2018-06-25
# 253755  11961831 2018-07-13 13:09:06  2018-06-26  FILTER ALGO 2018-06-26
# 253756  11961831 2018-07-13 13:09:06  2018-06-27  FILTER ALGO 2018-06-27
# 253757  11961831 2018-07-13 13:09:06  2018-06-28  FILTER ALGO 2018-06-28
# 253758  11961831 2018-07-13 13:09:06  2018-06-29  FILTER ALGO 2018-06-29
# 253759  11961831 2018-07-13 13:09:06  2018-06-30  FILTER ALGO 2018-06-30
#
#              ITEM_NUM         GOODS_NAME  \
# 253731  B000000114806  포레오 UFO 마스크 디바이스
# 253732  B000000114806  포레오 UFO 마스크 디바이스
# 253733  B000000114806  포레오 UFO 마스크 디바이스
# 253734  B000000114806  포레오 UFO 마스크 디바이스
# 253735  B000000114806  포레오 UFO 마스크 디바이스
# 253736  B000000114806  포레오 UFO 마스크 디바이스
# 253737  B000000114806  포레오 UFO 마스크 디바이스
# 253738  B000000114806  포레오 UFO 마스크 디바이스
# 253739  B000000114806  포레오 UFO 마스크 디바이스
# 253740  B000000114806  포레오 UFO 마스크 디바이스
# 253741  B000000114806  포레오 UFO 마스크 디바이스
# 253742  B000000114806  포레오 UFO 마스크 디바이스
# 253743  B000000114806  포레오 UFO 마스크 디바이스
# 253744  B000000114806  포레오 UFO 마스크 디바이스
# 253745  B000000114806  포레오 UFO 마스크 디바이스
# 253746  B000000114806  포레오 UFO 마스크 디바이스
# 253747  B000000114806  포레오 UFO 마스크 디바이스
# 253748  B000000114806  포레오 UFO 마스크 디바이스
# 253749  B000000114806  포레오 UFO 마스크 디바이스
# 253750  B000000114806  포레오 UFO 마스크 디바이스
# 253751  B000000114806  포레오 UFO 마스크 디바이스
# 253752  B000000114806  포레오 UFO 마스크 디바이스
# 253753  B000000114806  포레오 UFO 마스크 디바이스
# 253754  B000000114806  포레오 UFO 마스크 디바이스
# 253755  B000000114806  포레오 UFO 마스크 디바이스
# 253756  B000000114806  포레오 UFO 마스크 디바이스
# 253757  B000000114806  포레오 UFO 마스크 디바이스
# 253758  B000000114806  포레오 UFO 마스크 디바이스
# 253759  B000000114806  포레오 UFO 마스크 디바이스
#
#                                               COLLECT_URL  NORMAL_PRICE_SITE  \
# 253731  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253732  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253733  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253734  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253735  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253736  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253737  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253738  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253739  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253740  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253741  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253742  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253743  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253744  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253745  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253746  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253747  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253748  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253749  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253750  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253751  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253752  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253753  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253754  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253755  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253756  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253757  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253758  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
# 253759  http://www.oliveyoung.co.kr/store/goods/getGoo...             353000
#
#        BRAND_NAME  SITE_NO  CATE_NAMES BRAND SELL
# 253731        미분류        4  스킨케어>마스크/팩  init    0
# 253732        미분류        4  스킨케어>마스크/팩  init    0
# 253733        미분류        4  스킨케어>마스크/팩  init    0
# 253734        미분류        4  스킨케어>마스크/팩  init    0
# 253735        미분류        4  스킨케어>마스크/팩  init    0
# 253736        미분류        4  스킨케어>마스크/팩  init    0
# 253737        미분류        4  스킨케어>마스크/팩  init    0
# 253738        미분류        4  스킨케어>마스크/팩  init    0
# 253739        미분류        4  스킨케어>마스크/팩  init    0
# 253740        미분류        4  스킨케어>마스크/팩  init    0
# 253741        미분류        4  스킨케어>마스크/팩  init    0
# 253742        미분류        4  스킨케어>마스크/팩  init    0
# 253743        미분류        4  스킨케어>마스크/팩  init    0
# 253744        미분류        4  스킨케어>마스크/팩  init    0
# 253745        미분류        4  스킨케어>마스크/팩  init    0
# 253746        미분류        4  스킨케어>마스크/팩  init    0
# 253747        미분류        4  스킨케어>마스크/팩  init    0
# 253748        미분류        4  스킨케어>마스크/팩  init    0
# 253749        미분류        4  스킨케어>마스크/팩  init    0
# 253750        미분류        4  스킨케어>마스크/팩  init    0
# 253751        미분류        4  스킨케어>마스크/팩  init    0
# 253752        미분류        4  스킨케어>마스크/팩  init    0
# 253753        미분류        4  스킨케어>마스크/팩  init    0
# 253754        미분류        4  스킨케어>마스크/팩  init    0
# 253755        미분류        4  스킨케어>마스크/팩  init    0
# 253756        미분류        4  스킨케어>마스크/팩  init    0
# 253757        미분류        4  스킨케어>마스크/팩  init    0
# 253758        미분류        4  스킨케어>마스크/팩  init    0
# 253759        미분류        4  스킨케어>마스크/팩  init    0

# %%
temp = OLI.groupby("ITEM_ID").STOCK_AMOUNT.nunique()
st = temp[temp==1].reset_index()
temp2 = old[old.ITEM_ID.isin(st.ITEM_ID)]
temp3 = temp2[temp2.STOCK_AMOUNT.isin([99,999,9999,99999,999999,9999999])]
temp3.STOCK_AMOUNT.unique()
# Out:
# array([99999.0], dtype=object)

# %%
temp = GSS.groupby("ITEM_ID").STOCK_AMOUNT.nunique()
st = temp[temp==1].reset_index()
temp2 = GSS[GSS.ITEM_ID.isin(st.ITEM_ID)]
temp3 = temp2[temp2.STOCK_AMOUNT.isin([99,999,9999,99999,999999,9999999])]
temp3.STOCK_AMOUNT.unique()
# Out:
# array([99.0, 999.0, 9999.0, 99999.0], dtype=object)

# %%
temp3.groupby()
# Out:
# (33295, 18)

# %%
temp = HMA.groupby("ITEM_ID").STOCK_AMOUNT.nunique()
st = temp[temp==1].reset_index()
temp2 = HMA[HMA.ITEM_ID.isin(st.ITEM_ID)]
temp3 = temp2[temp2.STOCK_AMOUNT.isin([99,999,9999,99999,999999,9999999])]
temp3.STOCK_AMOUNT.unique()
# Out:
# array([999.0, 99.0, 999999.0, 9999.0, 99999.0], dtype=object)

# %% [markdown]
# ## URL 뽑기

# %%
AP = "12819911 2313319 7563091 3856973 12081822 12819947 12819943 12819948 12081825 12803503".split(" ")
LG = "3059399 4044564 3550578 3857804 2030249 4044557 3855427 3858137 2032728 2729103".split(" ")
LOREAL = "12850037 12850038 12808816 1838281 8845990 10365990".split(" ")
LVMH = "12803502 3854124 12795432 1807377 3236579 12803524 1835433 11548531 1852738 12752682".split(" ")

# %%
AP = [int(i) for i in AP]
LG = [int(i) for i in LG]
LOREAL = [int(i) for i in LOREAL]
LVMH = [int(i) for i in LVMH]

# %%
l1 = HMA[HMA.ITEM_ID.isin(AP)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l2 = HMA[HMA.ITEM_ID.isin(LG)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l3 = HMA[HMA.ITEM_ID.isin(LOREAL)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l4 = HMA[HMA.ITEM_ID.isin(LVMH)][['COLLECT_URL', 'BRAND']].drop_duplicates()

# %%
pd.concat([l1,l2,l3,l4]).to_csv("HMA.csv")

# %%
AP = "8750156 12721985 12721996 12794053 12722000 12756680 12597033 12609406 1445434 12733865".split(" ")
LG = "12625490 12625344 12180291 12625467 12625354 12625461 12392147 12625393 12625392 12755019".split(" ")
LOREAL = "5312607 5312588 5319995 5312598 5312606 4338237 5319964 4337644 5320003 1760318".split(" ")
LVMH = "12722022 12625534 12625535 12834127 12834129 12625253 6672884 12834128 12834130".split(" ")

# %%
AP = [int(i) for i in AP]
LG = [int(i) for i in LG]
LOREAL = [int(i) for i in LOREAL]
LVMH = [int(i) for i in LVMH]

# %%
l1 = GSS[GSS.ITEM_ID.isin(AP)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l2 = GSS[GSS.ITEM_ID.isin(LG)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l3 = GSS[GSS.ITEM_ID.isin(LOREAL)][['COLLECT_URL', 'BRAND']].drop_duplicates()
l4 = GSS[GSS.ITEM_ID.isin(LVMH)][['COLLECT_URL', 'BRAND']].drop_duplicates()

# %%
pd.concat([l1,l2,l3,l4]).to_csv("GSS.csv")

# %%
l2
# Out:
#                                               COLLECT_URL BRAND
# 24892     http://www.gsshop.com/prd/prd.gs?prdid=31693355    LG
# 73036     http://www.gsshop.com/prd/prd.gs?prdid=31693366    LG
# 118171  http://www.gsshop.com/deal/deal.gs?dealNo=3138...    LG
# 121503    http://www.gsshop.com/prd/prd.gs?prdid=31693348    LG
# 175726    http://www.gsshop.com/prd/prd.gs?prdid=31693344    LG
# 177656    http://www.gsshop.com/prd/prd.gs?prdid=31690595    LG
# 209942    http://www.gsshop.com/prd/prd.gs?prdid=31622137    LG
# 209963    http://www.gsshop.com/prd/prd.gs?prdid=31693346    LG
# 221434    http://www.gsshop.com/prd/prd.gs?prdid=31693339    LG
# 266312    http://www.gsshop.com/prd/prd.gs?prdid=31582059    LG

# %%
GSS[GSS.ITEM_ID==12819911]
# Out:
# Empty DataFrame
# Columns: [SELL_AMOUNT, STOCK_AMOUNT, REVISE_STOCK_AMOUNT, STOCK_ID, ITEM_ID, UPT_DT, COLLECT_DAY, UPT_ID, REG_DT, ITEM_NUM, GOODS_NAME, COLLECT_URL, NORMAL_PRICE_SITE, BRAND_NAME, SITE_NO, CATE_NAMES, BRAND, SELL]
# Index: []
