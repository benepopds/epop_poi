# %% [markdown]
# import ipy_autoreload
# %autoreload 2

# %%
import os, pandas as pd, pickle
from datetime import datetime, timedelta
# print (os.getcwd())

batch_day_count = 1000
industry = 'beauty'
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)

try:    
    indexDt = pickle.load(open('indexDt.'+industry, 'rb'))
except:
    indexDt = datetime.strptime('2018-01-23', '%Y-%m-%d') # fixed min DT

dates = list (pd.date_range(indexDt, today)) # datetimeIndex to list of Timestamp class

# %% [raw]
# pd.date_range(indexDt, today)

# %%
indexDt
# Out:
# datetime.datetime(2018, 1, 23, 0, 0)

# %%
dates = dates[0:37]
dates
# Out:
# [Timestamp('2018-01-23 00:00:00', freq='D'),
#  Timestamp('2018-01-24 00:00:00', freq='D'),
#  Timestamp('2018-01-25 00:00:00', freq='D'),
#  Timestamp('2018-01-26 00:00:00', freq='D'),
#  Timestamp('2018-01-27 00:00:00', freq='D'),
#  Timestamp('2018-01-28 00:00:00', freq='D'),
#  Timestamp('2018-01-29 00:00:00', freq='D'),
#  Timestamp('2018-01-30 00:00:00', freq='D'),
#  Timestamp('2018-01-31 00:00:00', freq='D'),
#  Timestamp('2018-02-01 00:00:00', freq='D'),
#  Timestamp('2018-02-02 00:00:00', freq='D'),
#  Timestamp('2018-02-03 00:00:00', freq='D'),
#  Timestamp('2018-02-04 00:00:00', freq='D'),
#  Timestamp('2018-02-05 00:00:00', freq='D'),
#  Timestamp('2018-02-06 00:00:00', freq='D'),
#  Timestamp('2018-02-07 00:00:00', freq='D'),
#  Timestamp('2018-02-08 00:00:00', freq='D'),
#  Timestamp('2018-02-09 00:00:00', freq='D'),
#  Timestamp('2018-02-10 00:00:00', freq='D'),
#  Timestamp('2018-02-11 00:00:00', freq='D'),
#  Timestamp('2018-02-12 00:00:00', freq='D'),
#  Timestamp('2018-02-13 00:00:00', freq='D'),
#  Timestamp('2018-02-14 00:00:00', freq='D'),
#  Timestamp('2018-02-15 00:00:00', freq='D'),
#  Timestamp('2018-02-16 00:00:00', freq='D'),
#  Timestamp('2018-02-17 00:00:00', freq='D'),
#  Timestamp('2018-02-18 00:00:00', freq='D'),
#  Timestamp('2018-02-19 00:00:00', freq='D'),
#  Timestamp('2018-02-20 00:00:00', freq='D'),
#  Timestamp('2018-02-21 00:00:00', freq='D'),
#  Timestamp('2018-02-22 00:00:00', freq='D'),
#  Timestamp('2018-02-23 00:00:00', freq='D'),
#  Timestamp('2018-02-24 00:00:00', freq='D'),
#  Timestamp('2018-02-25 00:00:00', freq='D'),
#  Timestamp('2018-02-26 00:00:00', freq='D'),
#  Timestamp('2018-02-27 00:00:00', freq='D'),
#  Timestamp('2018-02-28 00:00:00', freq='D')]

# %%
len(dates)*0.2
# Out:
# 7.800000000000001

# %%
from ci_db import get_ci_revisit_regDt, get_ci_company_by_id, get_ci_adid,revisit_in_dt_df_write,filter_industry,load_snapshot

# %%
start_time =datetime.now()
#dates=dates[15:17]

for index, day in enumerate(dates):
    
    print('=======processing :',round((index+1) / len(dates)*100),'%')
    #in_companies와 included_companyid, in_users와 included_userid  각각 같은 파일에서 나온다
    in_revisits, in_users, in_companies, all_userid, included_userid, included_companyid, nonincluded_userid, nonincluded_companyid = load_snapshot(industry)
    
    try:
        #1) revisit_day : "temp variable"
        #03.02 get_ci_revisit_regDt() query문 수정
        revisit_day = get_ci_revisit_regDt(day)[['EPOPCON_ID','COMPANY_ID','DEAL_DT','PAYMENT','CARD_NAME','ISSUED_COMPANY_ID', 'REG_DT']]

        #1-2) company_day : "temp variable"  == revisit_day의 compid 
        compid_day = list(set(revisit_day.COMPANY_ID.unique().tolist())- set(included_companyid+nonincluded_companyid))
        companies_day = get_ci_company_by_id(compid_day)[['ID', 'CO_NAME', 'CO_NAME_R', 'CATE', 'CATE1', 'TAG']]
        companies_day = companies_day[companies_day['CO_NAME_R'].notnull()]
        companies_day['COMPANY_ID'] = companies_day['ID'].astype(int)
        del companies_day['ID']    

        #1-3) all_userid : revisit_day의 userid  추가하기
        all_userid = list(set(revisit_day.EPOPCON_ID.unique().tolist() + all_userid)) 
        pickle.dump(all_userid, open('user_all.'+industry, 'wb'))
    except:
        print(d, 'no revisit_day or no company_id')
        pickle.dump(d + timedelta(days=1), open('indexDt.'+industry, 'wb'))
        continue    
    
    # 2) filtering : by using keyword : company_day -> included or not
    # in_companies_day, nonincluded_compid_day  : "temp variable" 
    in_companies_day, nonincluded_compid_day = filter_industry(companies_day, industry)
    
    # 2-1) nonincluded_companyid 추가하기
    nonincluded_companyid = list(set ( nonincluded_companyid + nonincluded_compid_day ) )
    pickle.dump(nonincluded_companyid, open('comp_ex.'+industry, 'wb'))
    
    # 2-2) in_companies 추가하기
    in_companies = in_companies.append(in_companies_day).drop_duplicates()
    pickle.dump(in_companies, open('comp_in.'+industry, 'wb'))
    
    # 2-3) in_revisits_day : "temp variable" == 회사명 기준 결제정보 필터링하기
    
    in_revisits_day = pd.merge(revisit_day, in_companies, how='inner', on='COMPANY_ID') # category info
    
    # 3) all_userid_day : temp variable
    # new userid만 찾아내기 위해 존재한다
    all_userid_day = list ( set(in_revisits_day.EPOPCON_ID.unique().tolist()) 
                      - set(included_userid + nonincluded_userid) )
    
    #try-except
    try:
        #3-1) users_day  : temp variable
        users_day = get_ci_adid(all_userid_day)

        #3-2) filtering : ad_id exists : users_day ->  included or not  
        in_users =  in_users.append(users_day[users_day.ADVTM_ID.notnull()]).drop_duplicates()
        pickle.dump(in_users, open('user_in.'+industry, 'wb'))

        nonincluded_userid = list(set(nonincluded_userid+users_day[users_day.ADVTM_ID.isnull()].EPOPCON_ID.unique().tolist()))
        pickle.dump(nonincluded_userid, open('user_ex.'+industry, 'wb'))
    except:
        print(d, 'no adid')
        pickle.dump(d + timedelta(days=1), open('indexDt.'+industry, 'wb'))
        continue
    
    #4) inserting merged-data to mezzo_car/beauty database
    revisit_in_dt_df_write(pd.merge(in_revisits_day, in_users, how='inner', on='EPOPCON_ID'), industry) # ad_id
        
    #5) looping 
    pickle.dump(day + timedelta(days=1), open('indexDt.'+industry, 'wb'))
    batch_day_count -= 1
    
    #5-1) completed messages
    print(len(revisit_day), 'pay records at', len(revisit_day.COMPANY_ID.unique().tolist()), 'stores.', len(compid_day), 'stores newly found,', len(in_revisits_day), 'beauty payments.')
    print(len(all_userid), 'total users,', len(in_users), 'total beauty users,' )
    print( len(included_userid), len(included_companyid))
    
    #6) end of looping
    if(batch_day_count <= 0 or index >= len(dates)-1):
        print('=========================================\n the process has done',datetime.now()-start_time)
        break
        
#print(a.shape, a.head())
# Out:
# =======processing : 3 %
# new revisit_in pickle
# new all user list pickle
# new industry in user df pickle
# new industry ex user list pickle
# new industry in comp df pickle
# new industry ex comp list pickle
# get_ci_revisit_regDt :  0:00:27.368121 563274 revisit records.
# get_ci_company_by_id :  0:01:28.391108 159482 company ids.
# get_ci_adid :  0:00:01.652395
# 563274 pay records at 160294 stores. 160294 stores newly found, 19519 beauty payments.
# 277717 total users, 16589 total beauty users,
# 0 0
# =======processing : 5 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:24.685680 561385 revisit records.
# get_ci_company_by_id :  0:00:31.462686 85067 company ids.
# get_ci_adid :  0:00:01.440831
# 561385 pay records at 158618 stores. 85860 stores newly found, 20017 beauty payments.
# 392335 total users, 31873 total beauty users,
# 16589 8067
# =======processing : 8 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.532869 593539 revisit records.
# get_ci_company_by_id :  0:00:19.650265 64590 company ids.
# get_ci_adid :  0:00:01.646380
# 593539 pay records at 162670 stores. 65432 stores newly found, 22787 beauty payments.
# 461901 total users, 47924 total beauty users,
# 31873 13208
# =======processing : 11 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.844873 613435 revisit records.
# get_ci_company_by_id :  0:00:15.630767 54879 company ids.
# get_ci_adid :  0:00:01.729716
# 613435 pay records at 170252 stores. 55696 stores newly found, 24124 beauty payments.
# 509721 total users, 63655 total beauty users,
# 47924 17716
# =======processing : 14 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.250817 617054 revisit records.
# get_ci_company_by_id :  0:00:13.180827 50228 company ids.
# get_ci_adid :  0:00:01.834881
# 617054 pay records at 173002 stores. 51066 stores newly found, 29257 beauty payments.
# 544385 total users, 81902 total beauty users,
# 63655 21874
# =======processing : 16 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:23.978758 516500 revisit records.
# get_ci_company_by_id :  0:00:06.170410 29902 company ids.
# get_ci_adid :  0:00:01.280405
# 516500 pay records at 137812 stores. 30619 stores newly found, 23028 beauty payments.
# 566461 total users, 95209 total beauty users,
# 81902 26925
# =======processing : 19 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:26.551070 583488 revisit records.
# get_ci_company_by_id :  0:00:08.627152 34243 company ids.
# get_ci_adid :  0:00:01.209243
# 583488 pay records at 165139 stores. 35012 stores newly found, 22075 beauty payments.
# 586723 total users, 107268 total beauty users,
# 95209 29896
# =======processing : 22 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:27.491236 572735 revisit records.
# get_ci_company_by_id :  0:00:06.243606 30011 company ids.
# get_ci_adid :  0:00:01.089899
# 572735 pay records at 164310 stores. 30781 stores newly found, 22102 beauty payments.
# 603283 total users, 118712 total beauty users,
# 107268 32882
# =======processing : 24 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.130012 610460 revisit records.
# get_ci_company_by_id :  0:00:06.490026 29352 company ids.
# get_ci_adid :  0:00:01.127484
# 610460 pay records at 170964 stores. 30171 stores newly found, 25162 beauty payments.
# 618920 total users, 130805 total beauty users,
# 118712 35526
# =======processing : 27 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.302580 607379 revisit records.
# get_ci_company_by_id :  0:00:06.614594 27882 company ids.
# get_ci_adid :  0:00:01.421761
# 607379 pay records at 170726 stores. 28693 stores newly found, 25317 beauty payments.
# 632617 total users, 142660 total beauty users,
# 130805 38415
# =======processing : 30 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:32.060069 633933 revisit records.
# get_ci_company_by_id :  0:00:05.980920 27321 company ids.
# get_ci_adid :  0:00:01.175126
# 633933 pay records at 179942 stores. 28157 stores newly found, 25670 beauty payments.
# 644915 total users, 154202 total beauty users,
# 142660 41134
# =======processing : 32 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.970055 616966 revisit records.
# get_ci_company_by_id :  0:00:05.103576 25228 company ids.
# get_ci_adid :  0:00:01.280406
# 616966 pay records at 176437 stores. 26057 stores newly found, 29090 beauty payments.
# 655504 total users, 167281 total beauty users,
# 154202 43861
# =======processing : 35 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:27.386473 529491 revisit records.
# get_ci_company_by_id :  0:00:02.889664 14940 company ids.
# get_ci_adid :  0:00:00.966572
# 529491 pay records at 135816 stores. 15622 stores newly found, 22931 beauty payments.
# 663781 total users, 177002 total beauty users,
# 167281 47129
# =======processing : 38 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:29.954774 585100 revisit records.
# get_ci_company_by_id :  0:00:03.878287 19742 company ids.
# get_ci_adid :  0:00:00.803137
# 585100 pay records at 164273 stores. 20532 stores newly found, 22458 beauty payments.
# 672679 total users, 186008 total beauty users,
# 177002 49022
# =======processing : 41 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.480754 582128 revisit records.
# get_ci_company_by_id :  0:00:03.288748 18307 company ids.
# get_ci_adid :  0:00:00.789077
# 582128 pay records at 164264 stores. 19100 stores newly found, 21845 beauty payments.
# 680599 total users, 194231 total beauty users,
# 186008 50905
# =======processing : 43 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:27.882162 601067 revisit records.
# get_ci_company_by_id :  0:00:03.087191 18154 company ids.
# get_ci_adid :  0:00:00.888361
# 601067 pay records at 169382 stores. 18958 stores newly found, 26563 beauty payments.
# 688121 total users, 203847 total beauty users,
# 194231 52689
# =======processing : 46 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:28.216082 593857 revisit records.
# get_ci_company_by_id :  0:00:03.257142 17661 company ids.
# get_ci_adid :  0:00:00.868307
# 593857 pay records at 171816 stores. 18497 stores newly found, 26074 beauty payments.
# 695504 total users, 213047 total beauty users,
# 203847 54764
# =======processing : 49 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:30.605432 632856 revisit records.
# get_ci_company_by_id :  0:00:03.420095 18655 company ids.
# get_ci_adid :  0:00:01.017708
# 632856 pay records at 185269 stores. 19521 stores newly found, 28793 beauty payments.
# 707308 total users, 222951 total beauty users,
# 213047 56705
# =======processing : 51 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:32.654859 648952 revisit records.
# get_ci_company_by_id :  0:00:03.540416 18005 company ids.
# get_ci_adid :  0:00:01.105915
# 648952 pay records at 183903 stores. 18886 stores newly found, 33635 beauty payments.
# 718885 total users, 234939 total beauty users,
# 222951 58654
# =======processing : 54 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:26.830367 549124 revisit records.
# get_ci_company_by_id :  0:00:01.946176 11020 company ids.
# get_ci_adid :  0:00:00.722923
# 549124 pay records at 142007 stores. 11712 stores newly found, 24372 beauty payments.
# 727514 total users, 243073 total beauty users,
# 234939 61195
# =======processing : 57 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:30.549243 635889 revisit records.
# get_ci_company_by_id :  0:00:02.730240 15539 company ids.
# get_ci_adid :  0:00:00.783082
# 635889 pay records at 177033 stores. 16339 stores newly found, 24373 beauty payments.
# 736655 total users, 250990 total beauty users,
# 243073 62709
# =======processing : 59 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:34.387445 712779 revisit records.
# get_ci_company_by_id :  0:00:03.598192 17463 company ids.
# get_ci_adid :  0:00:00.757996
# 712779 pay records at 190066 stores. 18348 stores newly found, 27736 beauty payments.
# 745830 total users, 259543 total beauty users,
# 250990 64421
# =======processing : 62 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.992394 742477 revisit records.
# get_ci_company_by_id :  0:00:03.295767 18530 company ids.
# get_ci_adid :  0:00:01.002667
# 742477 pay records at 203708 stores. 19501 stores newly found, 33184 beauty payments.
# 753740 total users, 269500 total beauty users,
# 259543 66173
# =======processing : 65 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:27.009985 501927 revisit records.
# get_ci_company_by_id :  0:00:01.976257 11428 company ids.
# get_ci_adid :  0:00:00.590572
# 501927 pay records at 137083 stores. 12126 stores newly found, 21627 beauty payments.
# 758790 total users, 275805 total beauty users,
# 269500 68185
# =======processing : 68 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:15.566433 335689 revisit records.
# get_ci_company_by_id :  0:00:00.849259 5521 company ids.
# get_ci_adid :  0:00:00.342890
# 335689 pay records at 88811 stores. 6039 stores newly found, 12174 beauty payments.
# 762462 total users, 278933 total beauty users,
# 275805 69307
# =======processing : 70 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:25.722931 474576 revisit records.
# get_ci_company_by_id :  0:00:01.509013 7972 company ids.
# get_ci_adid :  0:00:00.598590
# 474576 pay records at 124605 stores. 8645 stores newly found, 22108 beauty payments.
# 767456 total users, 284936 total beauty users,
# 278933 69554
# =======processing : 73 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:26.678795 502188 revisit records.
# get_ci_company_by_id :  0:00:01.379416 7685 company ids.
# get_ci_adid :  0:00:00.631654
# 502188 pay records at 131112 stores. 8346 stores newly found, 23749 beauty payments.
# 772438 total users, 291631 total beauty users,
# 284936 70263
# =======processing : 76 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.525172 646906 revisit records.
# get_ci_company_by_id :  0:00:02.827520 15477 company ids.
# get_ci_adid :  0:00:00.828203
# 646906 pay records at 178832 stores. 16311 stores newly found, 25299 beauty payments.
# 779038 total users, 298685 total beauty users,
# 291631 71330
# =======processing : 78 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.727272 677654 revisit records.
# get_ci_company_by_id :  0:00:02.376320 13612 company ids.
# get_ci_adid :  0:00:00.669805
# 677654 pay records at 178436 stores. 14468 stores newly found, 26485 beauty payments.
# 785334 total users, 305558 total beauty users,
# 298685 72763
# =======processing : 81 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.811890 651172 revisit records.
# get_ci_company_by_id :  0:00:02.606934 12617 company ids.
# get_ci_adid :  0:00:00.652737
# 651172 pay records at 179789 stores. 13425 stores newly found, 24844 beauty payments.
# 791064 total users, 311887 total beauty users,
# 305558 74110
# =======processing : 84 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:32.094368 646258 revisit records.
# get_ci_company_by_id :  0:00:02.184804 11832 company ids.
# get_ci_adid :  0:00:00.893379
# 646258 pay records at 180352 stores. 12671 stores newly found, 24585 beauty payments.
# 796316 total users, 318113 total beauty users,
# 311887 75422
# =======processing : 86 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:33.058721 665808 revisit records.
# get_ci_company_by_id :  0:00:02.149718 11943 company ids.
# get_ci_adid :  0:00:00.593581
# 665808 pay records at 187835 stores. 12801 stores newly found, 25350 beauty payments.
# 801153 total users, 324237 total beauty users,
# 318113 76694
# =======processing : 89 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:29.942981 648738 revisit records.
# get_ci_company_by_id :  0:00:01.833877 11182 company ids.
# get_ci_adid :  0:00:00.637696
# 648738 pay records at 186072 stores. 12040 stores newly found, 30085 beauty payments.
# 805387 total users, 331659 total beauty users,
# 324237 77993
# =======processing : 92 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:25.152903 540325 revisit records.
# get_ci_company_by_id :  0:00:01.157078 7072 company ids.
# get_ci_adid :  0:00:00.574529
# 540325 pay records at 146710 stores. 7820 stores newly found, 26178 beauty payments.
# 809152 total users, 337863 total beauty users,
# 331659 79542
# =======processing : 95 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:30.999454 664167 revisit records.
# get_ci_company_by_id :  0:00:01.853532 10438 company ids.
# get_ci_adid :  0:00:00.562497
# 664167 pay records at 183007 stores. 11263 stores newly found, 26797 beauty payments.
# 813743 total users, 343924 total beauty users,
# 337863 80423
# =======processing : 97 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:31.545435 660482 revisit records.
# get_ci_company_by_id :  0:00:01.703530 10348 company ids.
# get_ci_adid :  0:00:00.555479
# 660482 pay records at 184121 stores. 11208 stores newly found, 27544 beauty payments.
# 817907 total users, 349934 total beauty users,
# 343924 81585
# =======processing : 100 %
# new revisit_in pickle
# get_ci_revisit_regDt :  0:00:31.285213 667777 revisit records.
# get_ci_company_by_id :  0:00:01.431810 9719 company ids.
# get_ci_adid :  0:00:00.517377
# 667777 pay records at 180654 stores. 10533 stores newly found, 27852 beauty payments.
# 822171 total users, 355504 total beauty users,
# 349934 82675
# =========================================
#  the process has done 0:36:55.121100

# %% [markdown]
# # INSERT BRAND_NAME TO MEZZO DB

# %%
xl_file = pd.read_excel('BRAND_PATTERN.xlsx',sheetname='Sheet1')
print(xl_file.shape)
xl_file.head()
# Out:
# (269, 2)
#   co_name     pattern
# 0    웰메이드        웰메이드
# 1     힐앤힐         힐앤힐
# 2      흄          ^흄
# 3  휴먼피부과       휴먼피부과
# 4     휠라   필라|휠라|FILA

# %% [raw]
# queryString = "UPDATE mezzo_beauty SET BRAND_NAME = '"+xl_file.iloc[258,0]+"' WHERE co_name REGEXP '"+xl_file.iloc[258,1]+"';"
#
# for i in range(len(xl_file.index)) :
#     queryString = "UPDATE mezzo_beauty SET BRAND_NAME = '"+xl_file.iloc[i,0]+"' WHERE co_name REGEXP '"+xl_file.iloc[i,1]+"';"
#     print(queryString)
#
# #14:35 start

# %% [raw]
# xl_file[xl_file['co_name']=='크로커다일 '].iloc[0,1].replace(" ", "")

# %%
import pymysql
# autocommit = true
start_time=datetime.now()

conn = pymysql.connect(host='192.168.0.50', user='eums', password='eums00!q', db='eums-shared2', charset='utf8', autocommit=True)
curs = conn.cursor(pymysql.cursors.DictCursor)

for i in range(len(xl_file.index)) : 
    queryString = "UPDATE mezzo_beauty SET BRAND_NAME = '"+xl_file.iloc[i,0]+"' WHERE REPLACE(co_name,'(주)','') REGEXP '"+xl_file.iloc[i,1].replace(" ", "")+"';"
    curs.execute(queryString)

curs.close()
conn.close()

print(datetime.now()-start_time)
# Out:
# 0:04:08.340944

# %% [markdown]
# ### Execute BRAND_COSMETICS.sql  (using MySQLdb later)

# %% [markdown]
# # EXPORT DB TO CSV FILE

# %%
from ci_db import read_mezzo,export_to_db
start_time=datetime.now()
# select * from mezzo_car( or mezzo_baeuty)
#car_df=read_mezzo ('car')
beauty_df=read_mezzo ('beauty')

# %%
# redefining orders and column names
#export_c = export_to_db(car_df)
export_b = export_to_db(beauty_df) # 할때마다 export_to_db() 수정필요-> 주석처리

#sample_c=export_c.iloc[:100]
sample_b=export_b.iloc[:100]


#export_c.to_csv('car.csv')
export_b.to_csv('beauty0302.csv')

#export_b.DEAL_DT.max()
print(datetime.now()-start_time)
sample_b.head()
# Out:
# empty 'ADVTM_ID' 11
# 2018-03-02 17:32:17.761585
# 2018-03-02 17:32:19.861170
# 0:00:57.054708
#               DEAL_DT                                  ADID BRAND_NAME  \
# 0 2018-01-27 23:29:04  adec4fcf-7e3c-4a23-bd8c-22f85629a273       올리브영
# 1 2018-02-13 14:14:30  adec4fcf-7e3c-4a23-bd8c-22f85629a273       올리브영
# 2 2018-02-06 23:09:21  adec4fcf-7e3c-4a23-bd8c-22f85629a273       올리브영
# 3 2018-02-13 13:09:12  adec4fcf-7e3c-4a23-bd8c-22f85629a273       올리브영
# 4 2018-01-27 09:17:57  adec4fcf-7e3c-4a23-bd8c-22f85629a273       올리브영
#
#        CO_NAME CATE CATE1   CARD_NAME CARD_COMP  \
# 0  올리브영 태평로1가점   뷰티   화장품  삼성카드(0529)      None
# 1    올리브영 시청역점   뷰티   화장품  신한카드(9*5*)      None
# 2    올리브영 시청역점   뷰티   화장품  신한카드(9*5*)      None
# 3  올리브영 태평로1가점   뷰티   화장품  삼성카드(0529)      None
# 4  올리브영 태평로1가점   뷰티   화장품  삼성카드(0529)      None
#
#                                           TAG PAYMENT  PAY_COUNT
# 0                  #생활, #미용, #가정, #화장품, #올리브영   10000        236
# 1  #쇼핑,#유통,올리브영,RE,드럭스토어,#드럭스토어,#생활,#올리브영,#가정    5000        236
# 2  #쇼핑,#유통,올리브영,RE,드럭스토어,#드럭스토어,#생활,#올리브영,#가정    5000        236
# 3                  #생활, #미용, #가정, #화장품, #올리브영    5000        236
# 4                  #생활, #미용, #가정, #화장품, #올리브영   -5000        236

# %% [markdown]
# # Check csv file

# %% [markdown]
# import pandas as pd
# data = pd.read_csv('beauty0302.csv')
# print(data.shape)
# data.head()

# %%
print(beauty_df.shape)
beauty_df[[ 'DEAL_DT', 'ADVTM_ID', 'BRAND_NAME', 'CO_NAME', 'CATE', 'CATE1', 'CARD_NAME', 'CARD_COMP', 'TAG', 'PAYMENT' ]].tail(15)
# Out:
# (924048, 16)
#                    DEAL_DT                              ADVTM_ID BRAND_NAME  \
# 924033 2018-02-28 23:52:57  2f8334ce-e011-46dd-b48e-00bc2d231bcd     에뛰드하우스
# 924034 2018-02-28 23:53:24  76de4097-7c3b-4d1e-a448-11fcd265f445       None
# 924035 2018-02-28 23:53:23  73c270d1-533b-47d9-92f5-9b831ac5886b      이니스프리
# 924036 2018-02-28 23:53:52  fbf86a78-c468-4f6a-8ef2-45b8b23158e4        더풋샵
# 924037 2018-02-28 23:54:33  4f2bfaf6-fee3-412f-8490-234784031237       None
# 924038 2018-02-28 23:55:05  e5a8060f-faa4-48f3-a838-6d4b26d163fb       None
# 924039 2018-02-28 23:55:36  a5afb94d-e864-461e-abf2-27c034852bbf        프라다
# 924040 2018-02-28 23:56:09  8aaa3f85-60f9-4cf0-a75e-06a030f2a20a       None
# 924041 2018-02-28 23:57:22  05bdabf9-fe82-425c-8b36-b6edb8fa0522       None
# 924042 2018-02-28 23:57:17  3b4ce5d7-3b29-46fb-a999-d4677e104d3c       None
# 924043 2018-02-28 23:58:18  43ddd67e-a123-4edc-a585-7f159b388a77       None
# 924044 2018-03-01 00:58:25  5c18b4c4-df90-413c-af01-8d9c2ab10d71       None
# 924045 2018-02-28 23:59:12  752ed68d-1286-4e52-9593-dab0dad4eaf5       None
# 924046 2018-02-28 23:59:16  ea4cfb72-fca0-40a9-801e-f5c5c197b1f5      ABC마트
# 924047 2018-02-28 23:59:28  6711fddf-59d6-4de2-8da2-b7e13fc9aa30       None
#
#               CO_NAME CATE CATE1     CARD_NAME CARD_COMP  \
# 924033  에뛰드하우스 이마트연제점   뷰티   화장품    하나카드(7*2*)      None
# 924034          바니스타일   패션    의류    삼성카드(0432)      None
# 924035    이니스프리 수원화서점   뷰티   화장품    삼성카드(1184)      None
# 924036      더풋샵 성신여대점   뷰티   마사지          농협카드      None
# 924037             롯데   뷰티   마사지    하나카드(9*1*)      None
# 924038            더블유   뷰티   화장품    기업BC(0871)      None
# 924039    프라다 롯데호텔면세점   패션    의류    농협BC(3069)      None
# 924040           진케이스   패션    보석  SC은행BC(9152)      None
# 924041         스킨 셀레네   뷰티   마사지    삼성카드(8909)      None
# 924042            1번가   패션  액세서리    우리카드(1784)      None
# 924043          데일리뷰티   뷰티    헤어    우리카드(3940)      None
# 924044        에이치앤리헤어   뷰티    헤어          현대카드      None
# 924045           인터블루   패션    의류    하나카드(4896)      None
# 924046    ABC마트 ST수유점   패션    신발    롯데카드(2*1*)      None
# 924047            스타일   패션    의류    농협BC(2367)      None
#
#                                       TAG   PAYMENT
# 924033                #쇼핑, #향수, #유통, #화장품     13000
# 924034               #패션, #생활, #가정, #의류판매     27200
# 924035        #화장품, #생활, #미용, #가정, #이니스프리     49700
# 924036              #더풋샵,#발관리,#생활,#미용,#가정     11000
# 924037               #피부관리, #생활, #미용, #가정  -1799000
# 924038           #쇼핑, #향수, #미용, #유통, #화장품    126960
# 924039    #쇼핑,#유통,#종합패션,#패션,#생활,#의류판매,#가정     95000
# 924040           #귀금속, #보석, #패션, #생활, #가정     32000
# 924041  #마사지, #미용, #뷰티, #피부, #체형관리, #피부미용     32000
# 924042                   #쇼핑,#유통,#귀금속,#시계     23500
# 924043             #연장,#생활,#미용,#가정,#속눈썹증모     74700
# 924044                   #생활,#미용실,#미용,#가정     34000
# 924045               #패션, #생활, #의류판매, #가정     36140
# 924046  #구두,#패션잡화점,#신발,#패션,#생활,#ABC마트,#가정     21500
# 924047               #패션, #생활, #가정, #의류판매     70900

# %%
emptyADID= beauty_df[beauty_df['ADVTM_ID']=='']
print(emptyADID.shape)
emptyADID.head()
# Out:
# (11, 16)
#        ADVTM_ID BRAND_NAME CARD_COMP   CARD_NAME CATE CATE1  COMPANY_ID  \
# 62681                 올리브영      None  신한체크(2*3*)   뷰티   화장품     5404034
# 438611                유니클로      None  우리카드(4700)   패션    의류      743036
# 497260                None      None  우리카드(4700)   패션    의류     6811287
# 601308                None      None  신한카드(1*9*)   뷰티    헤어     6658272
# 601309                None      None  롯데카드(4*0*)   패션    의류     6961247
#
#               CO_NAME     CO_NAME_R             DEAL_DT  \
# 62681      올리브영 시흥대야점     올리브영시흥대야점 2018-01-26 12:50:59
# 438611  유니클로 대구동성로중앙점  유니클로대구동성로중앙점 2018-01-25 15:11:16
# 497260     (주)클랍핸즈스토어       클랍핸즈스토어 2018-02-12 18:41:02
# 601308         샤넬헤어케어        샤넬헤어케어 2018-01-29 18:06:03
# 601309           더스토리          더스토리 2018-02-10 23:01:16
#
#                             EPOPCON_ID      ID ISSUED_COMPANY_ID PAYMENT  \
# 62681   eppcn15a2e18768c0c245990ee4d61   62719                 2   22600
# 438611  eppcn15a7ecb3a8c0c243d38b36fc5  438722                 6  152500
# 497260  eppcn15a7ecb3a8c0c243d38b36fc5  497375                 6   31200
# 601308  eppcn15a86358a8c0c243d38b3715c  601436                 2   30000
# 601309  eppcn15a86358a8c0c243d38b3715c  601437                10  140000
#
#                     REG_DT                                 TAG
# 62681  2018-01-26 12:51:05  올리브영,RE,드럭스토어,#드럭스토어,#생활,#올리브영,#가정
# 438611 2018-02-10 19:37:24         #패션, #유니클로, #생활, #의류판매, #가정
# 497260 2018-02-12 18:42:19                #패션, #생활, #가정, #의류판매
# 601308 2018-02-16 10:37:36                 #생활, #미용실, #미용, #가정
# 601309 2018-02-16 10:37:36                #패션, #생활, #가정, #의류판매

# %%
print(export_b.shape)
export_b[[ 'DEAL_DT', 'ADID', 'BRAND_NAME', 'CO_NAME', 'CATE', 'CATE1', 'CARD_NAME', 'CARD_COMP', 'TAG', 'PAYMENT' ]].tail()
# Out:
# (924037, 11)
#                    DEAL_DT                                  ADID BRAND_NAME  \
# 924032 2018-02-24 13:07:51  2372e359-1a2e-400b-b4f4-d9571ef56f61       None
# 924033 2018-02-12 12:32:35  dd28bfab-3fed-493b-bd39-1ba35eaa4a20       올리브영
# 924034 2018-02-24 12:21:13  7b029c41-9a99-4bcc-9b6a-79928302221a       올리브영
# 924035 2018-02-24 13:46:15  bc4272cd-697d-4c08-93ee-adc45be093c2       올리브영
# 924036 2018-02-06 15:07:05  0d4bf939-e0cd-4add-83b1-55640b9d3367        애터미
#
#               CO_NAME CATE CATE1   CARD_NAME CARD_COMP  \
# 924032          웰빙앤스파   뷰티   마사지        현대카드      None
# 924033   올리브영 신정네거리역점   뷰티   화장품  신한체크(7*9*)      None
# 924034  올리브영 씨지브이북수원점   뷰티   화장품  삼성카드(8447)      None
# 924035  올리브영 씨지브이북수원점   뷰티   화장품  우리카드(6924)      None
# 924036         애터미하우스   뷰티   화장품  신한체크(8*4*)      None
#
#                                        TAG PAYMENT
# 924032                #피부관리, #생활, #미용, #가정   40000
# 924033  올리브영,RE,드럭스토어,#드럭스토어,#생활,#올리브영,#가정    8600
# 924034          #생활, #미용, #가정, #화장품, #올리브영  -50000
# 924035          #생활, #미용, #가정, #화장품, #올리브영    6000
# 924036                #기타,#화장품,#생활,#미용,#가정   46700

# %% [markdown]
# * 이틀치 했을때 5만개 정도 CSV DATA 만들어짐
