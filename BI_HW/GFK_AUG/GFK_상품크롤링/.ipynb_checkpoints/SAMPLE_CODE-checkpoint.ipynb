# %%
from bs4 import BeautifulSoup
import requests, pandas as pd
import re
from tqdm import tqdm

# %%
# web_url에 원하는 웹의 URL을 넣어주시면 됩니다.
r = requests.get("http://www.gsshop.com/prd/prd.gs?prdid=29919256")
print(r.status_code)
print(r.headers['content-type'])
# r.encoding
# r.text
# Out:
# 200
# text/html;charset=UTF-8

# %%
soup = BeautifulSoup(r.text, 'html.parser')


title = soup.find('p', {'class' : 'product-title'}).text

# id=ex_id인 div 태그를 가져와서 # 그 태그들 안에서 p 태그를 가져온다.
div_sales = soup.find("div", {"class":"product-feature-bar_column-right"})
num_sales = div_sales.find("strong",{"id":"ordQtyText"}).text
num_sales = "".join(re.findall('\d',num_sales))

# id=ex_id인 div 태그를 가져와서
a_review = soup.find("a", {"class":"customer-reviews-link-count"})
num_review = a_review.find("em").text
num_review = "".join(re.findall('\d',num_review)) 

# id=ex_id인 div 태그를 가져와서
span_discnt = soup.find("span", {"class":"price-definition-percent"})
num_discnt = span_discnt.find("em").text

# a = dict('title'=title,'num_sales'=num_sales,'num_review'=num_review,'num_discnt'=num_discnt)
a = dict(title=title,num_sales=num_sales,num_review=num_review,num_discnt=num_discnt)
print(a)
# Out:
# {'title': '[TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8', 'num_sales': '1628', 'num_review': '156', 'num_discnt': '12'}

# %%
def crawler(weburl,lists):
    r = requests.get(weburl)
    soup = BeautifulSoup(r.text, 'html.parser')
    #title
    title = soup.find('p', {'class' : 'product-title'}).text
    
    try:# qty
        div_sales = soup.find("div", {"class":"product-feature-bar_column-right"})
        num_sales = div_sales.find("strong",{"id":"ordQtyText"}).text
        num_sales = "".join(re.findall('\d',num_sales))
    except:
        num_sales=-1
        
    
    try:# reviews
        a_review = soup.find("a", {"class":"customer-reviews-link-count"})
        num_review = a_review.find("em").text
        num_review = "".join(re.findall('\d',num_review))
    except:
        num_review=0
        
    try: #discnt_pct
        span_discnt = soup.find("span", {"class":"price-definition-percent"})
        num_discnt = span_discnt.find("em").text
    except:
        num_discnt =0
        
    lists.append(dict(title=title,num_sales=num_sales,num_review=num_review,num_discnt=num_discnt,URL=weburl[7:]))

# %%
data = pd.read_pickle('청소기.pk')

# %%
print(data.shape)
data.head(1)
# Out:
# (154, 2)
#    SOURCE                                       URL
# 0  전체-인기순  www.gsshop.com/prd/prd.gs?prdid=32376489

# %%
temp = []
for index, value in tqdm(data.iterrows()):
    try:
        crawler(str('http://'+value.URL),temp)
    except:
        print(index, value)
yap2 = pd.DataFrame(temp)
# Out:
# 154it [01:33,  1.65it/s]

# %%
result = pd.merge(yap2,data,how='left',on='URL')
yap2.num_sales=result['num_sales'].astype(int)
yap2.num_review=result['num_review'].astype(int)
yap2.sort_values(by=['num_sales','num_review'],ascending=False).to_pickle('청소기_crawl.pk')
yap2[yap2['num_sales']>10000].nlargest(10, 'num_review').to_pickle('cb1.pk')

# %%
yap.head(1)
# Out:
#                                         URL num_discnt num_review num_sales  \
# 0  www.gsshop.com/prd/prd.gs?prdid=29919256         12        156      1628
#
#                                        title
# 0  [TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8

# %%
result = pd.merge(yap,data,how='left',on='URL')
print(result.shape)
result.head(1)
# Out:
# (117, 6)
#                                         URL num_discnt num_review num_sales  \
# 0  www.gsshop.com/prd/prd.gs?prdid=29919256         12        156      1628
#
#                                        title  SOURCE
# 0  [TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8  전체-인기순

# %%
# result['num_discnt']=result['num_discnt'].astype(int)
# result.num_review=result['num_review'].astype(int)
yap.num_sales=result['num_sales'].astype(int)
yap.sort_values(by=['num_sales','num_review'],ascending=False)#.to_pickle('냉장고_crawl.pk')
# Out:
#                                                    URL num_discnt num_review  \
# 1             www.gsshop.com/prd/prd.gs?prdid=31158094          9         50
# 63            www.gsshop.com/prd/prd.gs?prdid=31630302          7         19
# 0             www.gsshop.com/prd/prd.gs?prdid=29919256         12        156
# 64            www.gsshop.com/prd/prd.gs?prdid=32373593          5          0
# 5             www.gsshop.com/prd/prd.gs?prdid=32370777          5          0
# 4             www.gsshop.com/prd/prd.gs?prdid=32370484          8          3
# 16            www.gsshop.com/prd/prd.gs?prdid=31155331          0         25
# 3             www.gsshop.com/prd/prd.gs?prdid=32172882          7         69
# 2             www.gsshop.com/prd/prd.gs?prdid=31161035          9         48
# 65            www.gsshop.com/prd/prd.gs?prdid=32373541          5          1
# 66            www.gsshop.com/prd/prd.gs?prdid=32373511          5          1
# 40            www.gsshop.com/prd/prd.gs?prdid=31319966          7        109
# 25            www.gsshop.com/prd/prd.gs?prdid=31115320          0          7
# 10            www.gsshop.com/prd/prd.gs?prdid=31016774          0         32
# 70   www.gsshop.com/prd/prd.gs?prdid=27519256&lseq=...          0         97
# 69   www.gsshop.com/prd/prd.gs?prdid=31016774&lseq=...          0         32
# 23            www.gsshop.com/prd/prd.gs?prdid=31781156          9         50
# 11            www.gsshop.com/prd/prd.gs?prdid=27519256          0         97
# 6             www.gsshop.com/prd/prd.gs?prdid=31009717          0         57
# 68   www.gsshop.com/prd/prd.gs?prdid=31009717&lseq=...          0         57
# 7             www.gsshop.com/prd/prd.gs?prdid=31177668         10         25
# 8             www.gsshop.com/prd/prd.gs?prdid=32377079          8        109
# 67            www.gsshop.com/prd/prd.gs?prdid=22705911          0          0
# 71   www.gsshop.com/prd/prd.gs?prdid=30667819&lseq=...          0         51
# 47            www.gsshop.com/prd/prd.gs?prdid=29733164          0         11
# 17            www.gsshop.com/prd/prd.gs?prdid=31980708          0         11
# 26            www.gsshop.com/prd/prd.gs?prdid=31353603          0         13
# 44            www.gsshop.com/prd/prd.gs?prdid=31980711          0          5
# 12            www.gsshop.com/prd/prd.gs?prdid=30667819          0         51
# 59            www.gsshop.com/prd/prd.gs?prdid=31158094          9         50
# ..                                                 ...        ...        ...
# 89   www.gsshop.com/prd/prd.gs?prdid=16274981&lseq=...          0        198
# 29            www.gsshop.com/prd/prd.gs?prdid=29375988          0         19
# 35            www.gsshop.com/prd/prd.gs?prdid=30667824          0         17
# 79   www.gsshop.com/prd/prd.gs?prdid=30667824&lseq=...          0         17
# 43            www.gsshop.com/prd/prd.gs?prdid=29537547          6         16
# 87   www.gsshop.com/prd/prd.gs?prdid=30581717&lseq=...          0         14
# 51            www.gsshop.com/prd/prd.gs?prdid=31244336          0         11
# 57            www.gsshop.com/prd/prd.gs?prdid=31308242          0         11
# 86   www.gsshop.com/prd/prd.gs?prdid=31244336&lseq=...          0         11
# 20            www.gsshop.com/prd/prd.gs?prdid=31158090          7        107
# 50            www.gsshop.com/prd/prd.gs?prdid=32373541          5          1
# 56            www.gsshop.com/prd/prd.gs?prdid=27645649          0          1
# 92   www.gsshop.com/prd/prd.gs?prdid=31921238&lseq=...          0          1
# 97   www.gsshop.com/prd/prd.gs?prdid=31921261&lseq=...          0          1
# 99   www.gsshop.com/prd/prd.gs?prdid=31921275&lseq=...          0          1
# 105  www.gsshop.com/prd/prd.gs?prdid=31921235&lseq=...          0          1
# 21            www.gsshop.com/prd/prd.gs?prdid=32414994          0          0
# 30            www.gsshop.com/prd/prd.gs?prdid=32373593          5          0
# 48            www.gsshop.com/prd/prd.gs?prdid=31189591          0          0
# 60            www.gsshop.com/prd/prd.gs?prdid=32370777          5          0
# 85   www.gsshop.com/prd/prd.gs?prdid=31189591&lseq=...          0          0
# 90   www.gsshop.com/prd/prd.gs?prdid=32254215&lseq=...          0          0
# 93   www.gsshop.com/prd/prd.gs?prdid=32314672&lseq=...          0          0
# 94   www.gsshop.com/prd/prd.gs?prdid=32314671&lseq=...          0          0
# 100  www.gsshop.com/prd/prd.gs?prdid=32345019&lseq=...          0          0
# 101  www.gsshop.com/prd/prd.gs?prdid=32314669&lseq=...          0          0
# 102  www.gsshop.com/prd/prd.gs?prdid=32314673&lseq=...          0          0
# 103  www.gsshop.com/prd/prd.gs?prdid=31921207&lseq=...          0          0
# 104  www.gsshop.com/prd/prd.gs?prdid=31921214&lseq=...          0          0
# 106  www.gsshop.com/prd/prd.gs?prdid=31921279&lseq=...          0          0
#
#      num_sales                                              title
# 1         1628  [TV쇼핑]LG DIOS 냉장고 S831SS35 실버 매직스페이스 821L + 코코...
# 63        1628  [TV쇼핑]딤채 김치냉장고 221L 뚜껑형 어반실버 LDL22BEMUSF + 홈세트...
# 0         1628          [TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8
# 64        1628  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 5          940  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + 주...
# 4          836  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 16         757                  LG 디오스 매직스페이스 냉장고 F871SS32 (870L)
# 3          731  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 2          731   [TV쇼핑]LG DIOS 냉장고 S831S32 메탈 821L + 코코젤리 블렌더 사은품
# 65         731  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 66         731  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 40         662  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 25         377                            LG 일반냉장고 B607SEM (592ℓ)
# 10         276                   LG 디오스 매직스페이스 냉장고 S831W32 (821L)
# 70         256                         LG 디오스 스탠드형 김치냉장고 K417SW11
# 69         237                   LG 디오스 매직스페이스 냉장고 S831W32 (821L)
# 23         161  [TV쇼핑]LG DIOS 냉장고 S831SS35 실버 매직스페이스 821L + EL...
# 11         132                         LG 디오스 스탠드형 김치냉장고 K417SW11
# 6          108                   LG 디오스 매직스페이스 냉장고 S831S30 (821L)
# 68          97                   LG 디오스 매직스페이스 냉장고 S831S30 (821L)
# 7           97  [TV쇼핑][삼성] 냉장고 H9000 RH81M8011S9 5도어 811L + 삼성...
# 8           97  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 67          97             [TV쇼핑]LG 디오스 4도어 냉장고 906L F918S11 메탈퓨어
# 71          90                             LG 일반냉장고 B477WM (480ℓ)
# 47          80                   공식인증점) 캐리어 냉장고 CRFT-D138VMD 무료설치
# 17          63                      대우전자 클라쎄 85L 소형 냉장고 FR-B093SW
# 26          58                  LG 디오스 매직스페이스 냉장고 S831TS35 (821L)
# 44          57                대우전자 클라쎄 144L 실속형 소형냉장고 FR-B151SDWK
# 12          52                             LG 일반냉장고 B477WM (480ℓ)
# 59          49  [TV쇼핑]LG DIOS 냉장고 S831SS35 실버 매직스페이스 821L + 코코...
# ..         ...                                                ...
# 89          -1                         LG 빙고 냉동고 F-A201GDW (200L)
# 29          -1        위니아 딤채 18년형 김치냉장고 EDL16AXMZGS/뚜껑형(153리터/2룸)
# 35          -1                             LG 일반냉장고 B267WM (254ℓ)
# 79          -1                             LG 일반냉장고 B267WM (254ℓ)
# 43          -1  [TV쇼핑]삼성 지펠 김치냉장고 스탠드형 327L RQ33M70B5S8 (직화오븐 ...
# 87          -1                         LG 디오스 냉장고 F871SS11 (870L)
# 51          -1              LG 상냉장 슬림 냉장고 M458P (452L) [1~2주배송지연]
# 57          -1                             바디럽 퓨어썸 주방용 (핸드/코브라타입)
# 86          -1              LG 상냉장 슬림 냉장고 M458P (452L) [1~2주배송지연]
# 20          -1  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 50          -1  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 56          -1        위니아 딤채 18년형 김치냉장고 WDQ57BSMZS/스탠드형(551리터/4룸)
# 92          -1                             삼성 진공청소기 [VC33M2130LR]
# 97          -1                             삼성 핸디스틱형 청소기 [VC-H70S]
# 99          -1                           삼성 업소용 청소기 [VW33M7510LK]
# 105         -1                             삼성 진공청소기 [VC44M21C0L1]
# 21          -1                     LG 컨버터블 패키지 냉동고 A328S [2주배송지연]
# 30          -1  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 48          -1                              LG 일반냉장고 B608S (592L)
# 60          -1  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + 주...
# 85          -1                              LG 일반냉장고 B608S (592L)
# 90          -1                          LG 6단 서랍 냉동고 A205S (200L)
# 93          -1                                삼성 핸디형 청소기 [VC-H22]
# 94          -1                               삼성 진공 청소기 [VC-TU52G]
# 100         -1         [배송2~3주소요] 삼성  POWER GUN 청소기 [VS75N8011KK]
# 101         -1                    삼성  POWER GUN 청소기 [VS80N8061KR]
# 102         -1                    삼성  POWER GUN 청소기 [VS80N8083KB]
# 103         -1                  삼성  POWER stick 청소기 [VS60M6010KG]
# 104         -1                             삼성 진공청소기 [VC33M4151LR]
# 106         -1                             삼성 침구청소기 [VH60F40UYDW]
#
# [107 rows x 5 columns]

# %%
yap.nlargest(10, 'num_sales')
# Out:
#                                          URL  num_discnt  num_review  \
# 0   www.gsshop.com/prd/prd.gs?prdid=29919256           9           0
# 1   www.gsshop.com/prd/prd.gs?prdid=31158094           9           0
# 63  www.gsshop.com/prd/prd.gs?prdid=31630302           0         152
# 64  www.gsshop.com/prd/prd.gs?prdid=32373593           0         103
# 5   www.gsshop.com/prd/prd.gs?prdid=32370777          10           0
# 4   www.gsshop.com/prd/prd.gs?prdid=32370484          10           0
# 16  www.gsshop.com/prd/prd.gs?prdid=31155331           0        8283
# 2   www.gsshop.com/prd/prd.gs?prdid=31161035           9           0
# 3   www.gsshop.com/prd/prd.gs?prdid=32172882           9           0
# 65  www.gsshop.com/prd/prd.gs?prdid=32373541           0          78
#
#     num_sales                                              title
# 0      1628.0          [TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8
# 1      1628.0  [TV쇼핑]LG DIOS 냉장고 S831SS35 실버 매직스페이스 821L + 코코...
# 63     1628.0  [TV쇼핑]딤채 김치냉장고 221L 뚜껑형 어반실버 LDL22BEMUSF + 홈세트...
# 64     1628.0  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 5       940.0  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + 주...
# 4       836.0  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 16      757.0                  LG 디오스 매직스페이스 냉장고 F871SS32 (870L)
# 2       731.0   [TV쇼핑]LG DIOS 냉장고 S831S32 메탈 821L + 코코젤리 블렌더 사은품
# 3       731.0  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 65      731.0  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...

# %%
yap.num_review=result['num_review'].astype(int)
yap.nlargest(10, 'num_review')
# Out:
#                                          URL  num_discnt  num_review  \
# 13  www.gsshop.com/prd/prd.gs?prdid=31746000           9       10892
# 14  www.gsshop.com/prd/prd.gs?prdid=32377219           9       10892
# 15  www.gsshop.com/prd/prd.gs?prdid=27128363           9       10892
# 8   www.gsshop.com/prd/prd.gs?prdid=32377079           5        8886
# 9   www.gsshop.com/prd/prd.gs?prdid=32370504           5        8886
# 10  www.gsshop.com/prd/prd.gs?prdid=31016774           5        8886
# 11  www.gsshop.com/prd/prd.gs?prdid=27519256           5        8886
# 12  www.gsshop.com/prd/prd.gs?prdid=30667819           7        8886
# 16  www.gsshop.com/prd/prd.gs?prdid=31155331           0        8283
# 49  www.gsshop.com/prd/prd.gs?prdid=31708008           0        2547
#
#     num_sales                                              title
# 13       -1.0  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 14       -1.0  [TV쇼핑]삼성 지펠 냉장고 T9000 4도어 856L RF85N9003G1/RF8...
# 15       -1.0                  LG 디오스 뚜껑식 김치냉장고 K227AW11E (219L)
# 8        97.0  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 9        -1.0  [TV쇼핑]삼성 지펠 냉장고 T9000 4도어 856L RF85N9003G1/RF8...
# 10      276.0                   LG 디오스 매직스페이스 냉장고 S831W32 (821L)
# 11      132.0                         LG 디오스 스탠드형 김치냉장고 K417SW11
# 12       52.0                             LG 일반냉장고 B477WM (480ℓ)
# 16      757.0                  LG 디오스 매직스페이스 냉장고 F871SS32 (870L)
# 49       -1.0         위니아 딤채 18년형 김치냉장고 EDL20AXMAGS/뚜껑형(200리터/2룸

# %%
yap.num_discnt=result['num_discnt'].astype(int)
yap.nlargest(2, 'num_discnt')
# Out:
#                                          URL  num_discnt  num_review  \
# 44  www.gsshop.com/prd/prd.gs?prdid=31980711          11         140
# 4   www.gsshop.com/prd/prd.gs?prdid=32370484          10           0
#
#     num_sales                                              title
# 44       57.0                대우전자 클라쎄 144L 실속형 소형냉장고 FR-B151SDWK
# 4       836.0  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...

# %%
yap.nsmallest(10,'num_sales')
# Out:
#                                          URL  num_discnt  num_review  \
# 9   www.gsshop.com/prd/prd.gs?prdid=32370504           5        8886
# 13  www.gsshop.com/prd/prd.gs?prdid=31746000           9       10892
# 14  www.gsshop.com/prd/prd.gs?prdid=32377219           9       10892
# 15  www.gsshop.com/prd/prd.gs?prdid=27128363           9       10892
# 18  www.gsshop.com/prd/prd.gs?prdid=27803631           0        1583
# 19  www.gsshop.com/prd/prd.gs?prdid=27775689           0        1583
# 20  www.gsshop.com/prd/prd.gs?prdid=31158090           9        1583
# 21  www.gsshop.com/prd/prd.gs?prdid=32414994           9        1583
# 22  www.gsshop.com/prd/prd.gs?prdid=30373980           9        1583
# 24  www.gsshop.com/prd/prd.gs?prdid=32370325           0         263
#
#     num_sales                                              title
# 9        -1.0  [TV쇼핑]삼성 지펠 냉장고 T9000 4도어 856L RF85N9003G1/RF8...
# 13       -1.0  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 14       -1.0  [TV쇼핑]삼성 지펠 냉장고 T9000 4도어 856L RF85N9003G1/RF8...
# 15       -1.0                  LG 디오스 뚜껑식 김치냉장고 K227AW11E (219L)
# 18       -1.0            위니아 딤채 18년형 김치냉장고 쁘띠 WDS10BPACR (100리터)
# 19       -1.0        위니아 딤채 18년형 김치냉장고 EDQ57BFRMT/스탠드형(551리터/4룸)
# 20       -1.0  [TV쇼핑]LG DIOS 냉장고 F871S30H 실버 매직스페이스 5도어 866L ...
# 21       -1.0                     LG 컨버터블 패키지 냉동고 A328S [2주배송지연]
# 22       -1.0  [TV쇼핑]LG 디오스 냉장고 F871NS73 노크온 매직스페이스 + LG코드제로 ...
# 24       -1.0  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...

# %%
# yap[(yap['num_sales']>=300)&(yap['num_review']>=50)].nlargest(20,'num_discnt')
yo = yap.nlargest(7,'num_sales')
# yo=yo.append(yap.nlargest(1, 'num_review'))
# yo = yap[(yap['num_sales']>=500)&((yap['num_review']>50))]
yo=yo.append(yap.nlargest(3, 'num_review'))
yo.to_pickle('cb_냉장고.pk')

# %%
yap[(yap['num_sales']>=500)]
yap.nlargest(7,'num_sales')
# Out:
#                                          URL  num_discnt  num_review  \
# 0   www.gsshop.com/prd/prd.gs?prdid=29919256           9           0
# 1   www.gsshop.com/prd/prd.gs?prdid=31158094           9           0
# 63  www.gsshop.com/prd/prd.gs?prdid=31630302           0         152
# 64  www.gsshop.com/prd/prd.gs?prdid=32373593           0         103
# 5   www.gsshop.com/prd/prd.gs?prdid=32370777          10           0
# 4   www.gsshop.com/prd/prd.gs?prdid=32370484          10           0
# 16  www.gsshop.com/prd/prd.gs?prdid=31155331           0        8283
#
#     num_sales                                              title
# 0      1628.0          [TV쇼핑]삼성 지펠 냉장고 유러피안 양문형 815L RS82M6000S8
# 1      1628.0  [TV쇼핑]LG DIOS 냉장고 S831SS35 실버 매직스페이스 821L + 코코...
# 63     1628.0  [TV쇼핑]딤채 김치냉장고 221L 뚜껑형 어반실버 LDL22BEMUSF + 홈세트...
# 64     1628.0  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + L...
# 5       940.0  [TV쇼핑]LG DIOS 냉장고 F841SN35 김치톡톡 프리스타일 836L + 주...
# 4       836.0  [TV쇼핑]삼성 지펠 냉장고 T9000 5도어 푸드쇼케이스 848L RF85N920...
# 16      757.0                  LG 디오스 매직스페이스 냉장고 F871SS32 (870L)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# num_sales 와 num_review의 관계

# Fixing random state for reproducibility

yap['num_sales']=yap['num_sales'].astype(float)
yap['num_review']=yap['num_review'].astype(float)
x = yap['num_sales'].values
y = yap['num_review'].values

# area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
#s=area, 
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-1726b0c04848> in <module>()
#      14 # area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
#      15 #s=area,
# ---> 16 plt.scatter(x, y, c=colors, alpha=0.5)
#      17 plt.show()
#
# c:\python36\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3355                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3356                          linewidths=linewidths, verts=verts,
# -> 3357                          edgecolors=edgecolors, data=data, **kwargs)
#    3358     finally:
#    3359         ax._hold = washold
#
# c:\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# c:\python36\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4035         else:
#    4036             try:
# -> 4037                 c_array = np.asanyarray(c, dtype=float)
#    4038                 if c_array.shape in xy_shape:
#    4039                     c = np.ma.ravel(c_array)
#
# c:\python36\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# TypeError: float() argument must be a string or a number, not 'function'

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.set(style="ticks", color_codes=True)
# #source별로 보기
# # tips = sns.load_dataset("tips")
# sns.catplot(x="num_discnt", y="num_sales", kind ='swarm',data=result,hue="SOURCE");

# %%
# 각 컬럼 기준으로 barchart그리기
